# %% [markdown]
# ### yolo v5를 학습시킨 모델을 불러와서 RoI crop

# %% [markdown]
# * train

# %%
# !cd /workspace/yolo/yolov5; python detect.py --source /workspace/pre_dataset2/train/0  \
                            --weights /workspace/yolo_detect_version4/ultra/weights/best.pt --conf 0.6 \
                            --project=/workspace/yolo_crop_version4/train_0 --save-crop
# Out:
# detect: weights=['/workspace/yolo_detect_version4/ultra/weights/best.pt'], source=/workspace/pre_dataset2/train/0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/workspace/yolo_crop_version4/train_0, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.8.10 torch-1.12.0.dev20220327+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24233MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients
# image 1/2418 /workspace/pre_dataset2/train/0/08141190-397.jpg: 480x640 (no detections), 5.7ms
# ...

# %%
# !cd /workspace/yolo/yolov5; python detect.py --source /workspace/pre_dataset2/train/1  \
                            --weights /workspace/yolo_detect_version4/ultra/weights/best.pt --conf 0.6 \
                            --project=/workspace/yolo_crop_version4/train_1 --save-crop
# Out:
# detect: weights=['/workspace/yolo_detect_version4/ultra/weights/best.pt'], source=/workspace/pre_dataset2/train/1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/workspace/yolo_crop_version4/train_1, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.8.10 torch-1.12.0.dev20220327+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24233MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients
# image 1/1304 /workspace/pre_dataset2/train/1/17734882-1897.jpg: 480x640 (no detections), 5.4ms
# ...

# %%
# !cd /workspace/yolo/yolov5; python detect.py --source /workspace/pre_dataset2/train/2  \
                            --weights /workspace/yolo_detect_version4/ultra/weights/best.pt --conf 0.6 \
                            --project=/workspace/yolo_crop_version4/train_2 --save-crop
# Out:
# detect: weights=['/workspace/yolo_detect_version4/ultra/weights/best.pt'], source=/workspace/pre_dataset2/train/2, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/workspace/yolo_crop_version4/train_2, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.8.10 torch-1.12.0.dev20220327+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24233MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients
# image 1/384 /workspace/pre_dataset2/train/2/15052546-153.jpg: 480x640 2 RoIs, 5.4ms
# ...

# %%
# !cd /workspace/yolo/yolov5; python detect.py --source /workspace/pre_dataset2/train/3  \
                            --weights /workspace/yolo_detect_version4/ultra/weights/best.pt --conf 0.6 \
                            --project=/workspace/yolo_crop_version4/train_3 --save-crop
# Out:
# detect: weights=['/workspace/yolo_detect_version4/ultra/weights/best.pt'], source=/workspace/pre_dataset2/train/3, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/workspace/yolo_crop_version4/train_3, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.8.10 torch-1.12.0.dev20220327+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24233MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients
# image 1/48 /workspace/pre_dataset2/train/3/16515019-3657.jpg: 480x640 1 RoI, 5.4ms
# ...

# %% [markdown]
# * valid

# %%
# !cd /workspace/yolo/yolov5; python detect.py --source /workspace/pre_dataset2/valid/0  \
                            --weights /workspace/yolo_detect_version4/ultra/weights/best.pt --conf 0.6 \
                            --project=/workspace/yolo_crop_version4/valid_0 --save-crop
# Out:
# detect: weights=['/workspace/yolo_detect_version4/ultra/weights/best.pt'], source=/workspace/pre_dataset2/valid/0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/workspace/yolo_crop_version4/valid_0, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.8.10 torch-1.12.0.dev20220327+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24233MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients
# image 1/542 /workspace/pre_dataset2/valid/0/16286568-865.jpg: 480x640 1 RoI, 5.4ms
# ...

# %%
# !cd /workspace/yolo/yolov5; python detect.py --source /workspace/pre_dataset2/valid/1  \
                            --weights /workspace/yolo_detect_version4/ultra/weights/best.pt --conf 0.6 \
                            --project=/workspace/yolo_crop_version4/valid_1 --save-crop
# Out:
# detect: weights=['/workspace/yolo_detect_version4/ultra/weights/best.pt'], source=/workspace/pre_dataset2/valid/1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/workspace/yolo_crop_version4/valid_1, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.8.10 torch-1.12.0.dev20220327+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24233MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients
# image 1/276 /workspace/pre_dataset2/valid/1/16535037-775.jpg: 480x640 4 RoIs, 5.2ms
# ...

# %%
# !cd /workspace/yolo/yolov5; python detect.py --source /workspace/pre_dataset2/valid/2  \
                            --weights /workspace/yolo_detect_version4/ultra/weights/best.pt --conf 0.6 \
                            --project=/workspace/yolo_crop_version4/valid_2 --save-crop
# Out:
# detect: weights=['/workspace/yolo_detect_version4/ultra/weights/best.pt'], source=/workspace/pre_dataset2/valid/2, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/workspace/yolo_crop_version4/valid_2, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.8.10 torch-1.12.0.dev20220327+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24233MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients
# image 1/79 /workspace/pre_dataset2/valid/2/09135989-431.jpg: 480x640 3 RoIs, 5.6ms
# ...

# %%
# !cd /workspace/yolo/yolov5; python detect.py --source /workspace/pre_dataset2/valid/3  \
                            --weights /workspace/yolo_detect_version4/ultra/weights/best.pt --conf 0.6 \
                            --project=/workspace/yolo_crop_version4/valid_3 --save-crop
# Out:
# detect: weights=['/workspace/yolo_detect_version4/ultra/weights/best.pt'], source=/workspace/pre_dataset2/valid/3, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/workspace/yolo_crop_version4/valid_3, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.8.10 torch-1.12.0.dev20220327+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24233MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients
# image 1/12 /workspace/pre_dataset2/valid/3/33011031-34.jpg: 480x640 4 RoIs, 6.0ms
# ...

# %% [markdown]
# * test

# %%
# !cd /workspace/yolo/yolov5; python detect.py --source /workspace/pre_dataset2/test/0  \
                            --weights /workspace/yolo_detect_version4/ultra/weights/best.pt --conf 0.6 \
                            --project=/workspace/yolo_crop_version4/test_0 --save-crop
# Out:
# detect: weights=['/workspace/yolo_detect_version4/ultra/weights/best.pt'], source=/workspace/pre_dataset2/test/0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/workspace/yolo_crop_version4/test_0, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.8.10 torch-1.12.0.dev20220327+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24233MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients
# image 1/428 /workspace/pre_dataset2/test/0/18022126-711.jpg: 480x640 (no detections), 5.7ms
# ...

# %%
# !cd /workspace/yolo/yolov5; python detect.py --source /workspace/pre_dataset2/test/1  \
                            --weights /workspace/yolo_detect_version4/ultra/weights/best.pt --conf 0.6 \
                            --project=/workspace/yolo_crop_version4/test_1 --save-crop
# Out:
# detect: weights=['/workspace/yolo_detect_version4/ultra/weights/best.pt'], source=/workspace/pre_dataset2/test/1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/workspace/yolo_crop_version4/test_1, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.8.10 torch-1.12.0.dev20220327+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24233MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients
# image 1/289 /workspace/pre_dataset2/test/1/15642367-107.jpg: 480x640 (no detections), 5.3ms
# ...

# %%
# !cd /workspace/yolo/yolov5; python detect.py --source /workspace/pre_dataset2/test/2  \
                            --weights /workspace/yolo_detect_version4/ultra/weights/best.pt --conf 0.6 \
                            --project=/workspace/yolo_crop_version4/test_2 --save-crop
# Out:
# detect: weights=['/workspace/yolo_detect_version4/ultra/weights/best.pt'], source=/workspace/pre_dataset2/test/2, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/workspace/yolo_crop_version4/test_2, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.8.10 torch-1.12.0.dev20220327+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24233MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients
# image 1/85 /workspace/pre_dataset2/test/2/18003048-433.jpg: 480x640 2 RoIs, 5.4ms
# ...

# %%
# !cd /workspace/yolo/yolov5; python detect.py --source /workspace/pre_dataset2/test/3  \
                            --weights /workspace/yolo_detect_version4/ultra/weights/best.pt --conf 0.6 \
                            --project=/workspace/yolo_crop_version4/test_3 --save-crop
# Out:
# detect: weights=['/workspace/yolo_detect_version4/ultra/weights/best.pt'], source=/workspace/pre_dataset2/test/3, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/workspace/yolo_crop_version4/test_3, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "tqdm>=4.64.0" not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.8.10 torch-1.12.0.dev20220327+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24233MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients
# image 1/17 /workspace/pre_dataset2/test/3/53351687-409.jpg: 480x640 7 RoIs, 5.6ms
# ...

# %% [markdown]
# * 경로 : RoI만 사용할 것이기에 따로 옮기기

# %%
import shutil

# %%
shutil.copytree('/workspace/yolo_crop_version4/train_0/exp/crops/RoI', '/workspace/yolo_RoI_version4_manu(0.6)/train/0')
# Out:
# '/workspace/yolo_RoI_version4_manu(0.6)/train/0'

# %%
shutil.copytree('/workspace/yolo_crop_version4/train_1/exp/crops/RoI', '/workspace/yolo_RoI_version4_manu(0.6)/train/1')
# Out:
# '/workspace/yolo_RoI_version4_manu(0.6)/train/1'

# %%
shutil.copytree('/workspace/yolo_crop_version4/train_2/exp/crops/RoI', '/workspace/yolo_RoI_version4_manu(0.6)/train/2')
# Out:
# '/workspace/yolo_RoI_version4_manu(0.6)/train/2'

# %%
shutil.copytree('/workspace/yolo_crop_version4/train_3/exp/crops/RoI', '/workspace/yolo_RoI_version4_manu(0.6)/train/3')
# Out:
# '/workspace/yolo_RoI_version4_manu(0.6)/train/3'

# %%
shutil.copytree('/workspace/yolo_crop_version4/valid_0/exp/crops/RoI', '/workspace/yolo_RoI_version4_manu(0.6)/valid/0')
# Out:
# '/workspace/yolo_RoI_version4_manu(0.6)/valid/0'

# %%
shutil.copytree('/workspace/yolo_crop_version4/valid_1/exp/crops/RoI', '/workspace/yolo_RoI_version4_manu(0.6)/valid/1')
# Out:
# '/workspace/yolo_RoI_version4_manu(0.6)/valid/1'

# %%
shutil.copytree('/workspace/yolo_crop_version4/valid_2/exp/crops/RoI', '/workspace/yolo_RoI_version4_manu(0.6)/valid/2')
# Out:
# '/workspace/yolo_RoI_version4_manu(0.6)/valid/2'

# %%
shutil.copytree('/workspace/yolo_crop_version4/valid_3/exp/crops/RoI', '/workspace/yolo_RoI_version4_manu(0.6)/valid/3')
# Out:
# '/workspace/yolo_RoI_version4_manu(0.6)/valid/3'

# %%
shutil.copytree('/workspace/yolo_crop_version4/test_0/exp/crops/RoI', '/workspace/yolo_RoI_version4_manu(0.6)/test/0')
# Out:
# '/workspace/yolo_RoI_version4_manu(0.6)/test/0'

# %%
shutil.copytree('/workspace/yolo_crop_version4/test_1/exp/crops/RoI', '/workspace/yolo_RoI_version4_manu(0.6)/test/1')
# Out:
# '/workspace/yolo_RoI_version4_manu(0.6)/test/1'

# %%
shutil.copytree('/workspace/yolo_crop_version4/test_2/exp/crops/RoI', '/workspace/yolo_RoI_version4_manu(0.6)/test/2')
# Out:
# '/workspace/yolo_RoI_version4_manu(0.6)/test/2'

# %%
shutil.copytree('/workspace/yolo_crop_version4/test_3/exp/crops/RoI', '/workspace/yolo_RoI_version4_manu(0.6)/test/3')
# Out:
# '/workspace/yolo_RoI_version4_manu(0.6)/test/3'

# %% [markdown]
# → train, valid, test set 구성 완료

# %% [markdown]
# * data check : yolo가 중복으로 예측한 것은 중복하여 사용

# %%
import os
def get_files_count(folder_path):
	dirListing = os.listdir(folder_path)
	return len(dirListing)

# %%
train_0 = get_files_count('/workspace/yolo_RoI_version4_manu(0.6)/train/0')
train_1 = get_files_count('/workspace/yolo_RoI_version4_manu(0.6)/train/1')
train_2 = get_files_count('/workspace/yolo_RoI_version4_manu(0.6)/train/2')
train_3 = get_files_count('/workspace/yolo_RoI_version4_manu(0.6)/train/3')

# %%
train_0_org = get_files_count('/workspace/pre_dataset2/train/0')
train_1_org = get_files_count('/workspace/pre_dataset2/train/1')
train_2_org = get_files_count('/workspace/pre_dataset2/train/2')
train_3_org = get_files_count('/workspace/pre_dataset2/train/3')

# %%
print(train_0, train_1, train_2, train_3)
# Out:
# 7422 3903 1096 150

# %%
print(train_0_org, train_1_org, train_2_org, train_3_org)
# Out:
# 2418 1304 384 48

# %%
valid_0 = get_files_count('/workspace/yolo_RoI_version4_manu(0.6)/valid/0')
valid_1 = get_files_count('/workspace/yolo_RoI_version4_manu(0.6)/valid/1')
valid_2 = get_files_count('/workspace/yolo_RoI_version4_manu(0.6)/valid/2')
valid_3 = get_files_count('/workspace/yolo_RoI_version4_manu(0.6)/valid/3')

# %%
valid_0_org = get_files_count('/workspace/pre_dataset2/valid/0')
valid_1_org = get_files_count('/workspace/pre_dataset2/valid/1')
valid_2_org = get_files_count('/workspace/pre_dataset2/valid/2')
valid_3_org = get_files_count('/workspace/pre_dataset2/valid/3')

# %%
print(valid_0, valid_1, valid_2, valid_3)
# Out:
# 1778 884 252 61

# %%
print(valid_0_org, valid_1_org, valid_2_org, valid_3_org)
# Out:
# 542 276 79 12

# %%
test_0 = get_files_count('/workspace/yolo_RoI_version4_manu(0.6)/test/0')
test_1 = get_files_count('/workspace/yolo_RoI_version4_manu(0.6)/test/1')
test_2 = get_files_count('/workspace/yolo_RoI_version4_manu(0.6)/test/2')
test_3 = get_files_count('/workspace/yolo_RoI_version4_manu(0.6)/test/3')

# %%
test_0_org = get_files_count('/workspace/pre_dataset2/test/0')
test_1_org = get_files_count('/workspace/pre_dataset2/test/1')
test_2_org = get_files_count('/workspace/pre_dataset2/test/2')
test_3_org = get_files_count('/workspace/pre_dataset2/test/3')

# %%
print(test_0, test_1, test_2, test_3)
# Out:
# 1286 920 254 59

# %%
print(test_0_org, test_1_org, test_2_org, test_3_org)
# Out:
# 428 289 85 17
